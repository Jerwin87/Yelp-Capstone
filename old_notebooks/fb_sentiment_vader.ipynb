# %%
import sys
# adding to the path variables the one folder higher (locally, not changing system variables)
sys.path.append("..")

import pandas as pd

import nltk
nltk.download("vader_lexicon")

from nltk.sentiment.vader import SentimentIntensityAnalyzer

from scripts.processing import *

from tqdm.auto import tqdm
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/felixbecker/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
sent_analyzer = SentimentIntensityAnalyzer()

# %%
df_senti = pd.read_csv('../data/yelp_dataset/review_1819.csv')

# %%
df_senti = language_processing(df_senti);
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# /Users/felixbecker/neuefische/Yelp-Capstone/notebooks/../scripts/processing.py:51: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_lang['language'] = df_lang['language'].str.replace('label',"").str.replace(r"[^a-zA-Z ]+","").str.strip();

# %%
df_senti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1612316 entries, 0 to 1813645
# Data columns (total 12 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Unnamed: 0   1612316 non-null  int64
#  1   review_id    1612316 non-null  object
#  2   user_id      1612316 non-null  object
#  3   business_id  1612316 non-null  object
#  4   stars        1612316 non-null  float64
#  5   useful       1612316 non-null  int64
#  6   funny        1612316 non-null  int64
#  7   cool         1612316 non-null  int64
#  8   text         1612316 non-null  object
#  9   date         1612316 non-null  object
#  10  year         1612316 non-null  int64
#  11  language     1612316 non-null  object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 159.9+ MB

# %%
df_senti.reset_index(inplace=True)

# %%
tqdm.pandas()

# %%
df_senti['sentiment'] = df_senti['text'].progress_apply(lambda x : sent_analyzer.polarity_scores(x))
# Out:
# 100%|██████████| 1612316/1612316 [15:07<00:00, 1776.28it/s]

# %%
df_senti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612316 entries, 0 to 1612315
# Data columns (total 14 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   index        1612316 non-null  int64
#  1   Unnamed: 0   1612316 non-null  int64
#  2   review_id    1612316 non-null  object
#  3   user_id      1612316 non-null  object
#  4   business_id  1612316 non-null  object
#  5   stars        1612316 non-null  float64
#  6   useful       1612316 non-null  int64
#  7   funny        1612316 non-null  int64
#  8   cool         1612316 non-null  int64
#  9   text         1612316 non-null  object
#  10  date         1612316 non-null  object
#  11  year         1612316 non-null  int64
#  12  language     1612316 non-null  object
#  13  sentiment    1612316 non-null  object
# dtypes: float64(1), int64(6), object(7)
# memory usage: 172.2+ MB

# %%
senti = df_senti['sentiment'].tolist()

# %%
len(senti)
# Out:
# 1612316

# %%
df_tmp = pd.DataFrame(senti)

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612316 entries, 0 to 1612315
# Data columns (total 4 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   neg       1612316 non-null  float64
#  1   neu       1612316 non-null  float64
#  2   pos       1612316 non-null  float64
#  3   compound  1612316 non-null  float64
# dtypes: float64(4)
# memory usage: 49.2 MB

# %%
df_senti_final = pd.concat([df_senti, df_tmp], axis=1)

# %%
df_senti_final.sample(20)
# Out:
#            index  Unnamed: 0               review_id                 user_id  \
# 146261    165036      618873  NJAHuFg2JxPpayBGqfFjGg  eaRPVRp5AndzvvngFrNgWg
# 499270    561788     2195121  dCVZTOjhTvSh8N0QkeErVA  yxOWlIYLJ0C0xZLGnhuZKg
# 673628    758266     3053957  cvhYHLn7LJFFlx2bjlavpA  l43sbucIybcyjLZbG6G01g
# 864867    973714     3866059  XsdDIv9Jdk4QuQpv-069xQ  JlgfXLdcysM97vSmbiABNg
# 43670    {'neg': 0.0, 'neu': 0.657, 'pos': 0.343, 'comp...  0.000  0.657
# 170730   {'neg': 0.061, 'neu': 0.836, 'pos': 0.103, 'co...  0.061  0.836
# 441537   {'neg': 0.013, 'neu': 0.845, 'pos': 0.142, 'co...  0.013  0.845
# 118893   {'neg': 0.101, 'neu': 0.711, 'pos': 0.188, 'co...  0.101  0.711
# 885630   {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'comp...  0.000  0.821
# 74373    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000
# 631614   {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'comp...  0.000  0.697
# 1520109  {'neg': 0.016, 'neu': 0.733, 'pos': 0.251, 'co...  0.016  0.733
# 801847   {'neg': 0.027, 'neu': 0.656, 'pos': 0.318, 'co...  0.027  0.656
#
#            pos  compound
# 146261   0.109    0.9435
# 499270   0.103    0.9173
# 673628   0.316    0.8279
# 864867   0.086   -0.6398
# 541739   0.507    0.9473
# 1510838  0.290    0.7319
# 1225510  0.033    0.2960
# 49355    0.387    0.9888
# 674701   0.349    0.9771
# 136667   0.076    0.8124
# 1078029  0.204    0.8947
# 43670    0.343    0.8555
# 170730   0.103    0.7787
# 441537   0.142    0.9440
# 118893   0.188    0.4742
# 885630   0.179    0.4840
# 74373    0.000    0.0000
# 631614   0.303    0.9582
# 1520109  0.251    0.9724
# 801847   0.318    0.9715

# %%
df_senti_final.drop('sentiment', axis=1, inplace=True)

# %%
df_senti_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612316 entries, 0 to 1612315
# Data columns (total 17 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   index        1612316 non-null  int64
#  1   Unnamed: 0   1612316 non-null  int64
#  2   review_id    1612316 non-null  object
#  3   user_id      1612316 non-null  object
#  4   business_id  1612316 non-null  object
#  5   stars        1612316 non-null  float64
#  6   useful       1612316 non-null  int64
#  7   funny        1612316 non-null  int64
#  8   cool         1612316 non-null  int64
#  9   text         1612316 non-null  object
#  10  date         1612316 non-null  object
#  11  year         1612316 non-null  int64
#  12  language     1612316 non-null  object
#  13  neg          1612316 non-null  float64
#  14  neu          1612316 non-null  float64
#  15  pos          1612316 non-null  float64
#  16  compound     1612316 non-null  float64
# dtypes: float64(5), int64(6), object(6)
# memory usage: 209.1+ MB

# %%
df_senti_final.to_csv('review_1819_sentiment.csv')

# %%
df = pd.read_csv('../data/yelp_dataset/review_1819_sentiment.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612316 entries, 0 to 1612315
# Data columns (total 18 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Unnamed: 0.1  1612316 non-null  int64
#  1   index         1612316 non-null  int64
#  2   Unnamed: 0    1612316 non-null  int64
#  3   review_id     1612316 non-null  object
#  4   user_id       1612316 non-null  object
#  5   business_id   1612316 non-null  object
#  6   stars         1612316 non-null  float64
#  7   useful        1612316 non-null  int64
#  8   funny         1612316 non-null  int64
#  9   cool          1612316 non-null  int64
#  10  text          1612316 non-null  object
#  11  date          1612316 non-null  object
#  12  year          1612316 non-null  int64
#  13  language      1612316 non-null  object
#  14  neg           1612316 non-null  float64
#  15  neu           1612316 non-null  float64
#  16  pos           1612316 non-null  float64
#  17  compound      1612316 non-null  float64
# dtypes: float64(5), int64(7), object(6)
# memory usage: 221.4+ MB
