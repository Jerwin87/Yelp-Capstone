# %% [markdown]
# Create dataframes out of .json-files

# %% [markdown]
# 1.) Business

# %%
import sys
# adding to the path variables the one folder higher (locally, not changing system variables)
sys.path.append("..")

# import needed functions
from modeling.processing import *

#read the full json
dfr = get_df('/Volumes/Samsung_T5/Data_Science_BootCamp/capstone/Yelp-Capstone/data/yelp_academic_dataset_business.json')

# save full file as csv
dfr.to_csv('/Volumes/Samsung_T5/Data_Science_BootCamp/capstone/Yelp-Capstone/data/business.csv')

# add year column and filter by it
#dfr['year'] = pd.to_datetime(dfr.date).dt.year
#df_two = dfr.query('2018 <= year <= 2019')

# save reduced df
#df_two.to_csv('/Volumes/Samsung_T5/Data_Science_BootCamp/capstone/Yelp-Capstone/data/')

# %% [markdown]
# 2.) Users

# %%
import sys
# adding to the path variables the one folder higher (locally, not changing system variables)
sys.path.append("..")

# import needed functions
from modeling.processing import *

#read the full json
dfr = get_df('/Volumes/Samsung_T5/Data_Science_BootCamp/capstone/Yelp-Capstone/data/yelp_academic_dataset_user.json')

# save full file as csv
dfr.to_csv('/Volumes/Samsung_T5/Data_Science_BootCamp/capstone/Yelp-Capstone/data/users.csv')

# %%
dfr.sample(10)
# Out:
#                         user_id       name  review_count        yelping_since  \
# 1895859  gl7zK4pVP1SBqqouF4Vopg     Tigran            18  2014-10-31 17:04:33
# 889437   6JivuHgKCX75dXEofDzUTQ       Drew             2  2013-09-10 18:54:58
# 1882654  JEyOvXbyNVKggRmVJXGEGw       Rita             3  2013-10-09 17:26:28
# 926673   aK_6vqoIG61Hk1Z4-3ETCw     Robert             2  2018-08-12 00:12:33
# 1410761  SzmAa_IOoMmIRlkjk2YEVg  Bridgette             9  2017-08-12 13:34:20
# 1320918  yypv621oto--IhZ7XvMOew       Beth             5  2019-04-12 16:58:46
# 1467099  xFW6D-dxhqO5I2M5ynEJUQ     Alicia            39  2014-02-18 15:24:55
# 538586   rEnqnXj5FARjZRHf3CKajg         M.            10  2013-04-18 14:17:35
# 1702227  3HXvoLLOh-YgSBKHl9spnA        Ray             7  2018-12-28 14:46:51
# 1119943  uFYCSvnjp-0gV_bXWNomEQ    Tiffani             1  2015-09-13 19:59:53
#
#          useful  funny  cool  elite  \
# 1895859      11      4     3
# 889437        0      0     0
# ...
